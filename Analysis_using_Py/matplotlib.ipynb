# %%
# %pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt

x = [1,2,8,5]
y = [2,5,8,4]
plt.plot(x,y)
plt.xlabel("X axis")
plt.ylabel("Y axis")
plt.title("Basic line plot")
plt.show()

# %%
#customized line plot

x = [1,2,3,5]
y = [2,5,2,4]
plt.plot(x,y, color="red", linestyle="--", marker="o",linewidth="3",markersize="8")
plt.grid(True)

# %%
#multiple plot 
x = [1,2,8,5]
y1 = [2,5,8,4]
y2 = [1,3,4,6]

plt.figure(figsize=(9,5))
plt.subplot(2,2,1)
plt.plot(x,y1, color="green")
plt.title("Plot 1")

plt.subplot(2,2,2)
plt.plot(x,y2, color="red")
plt.title("Plot 2")

plt.subplot(2,2,3)
plt.plot(y1,x, color="yellow")
plt.title("Plot 3")

plt.show()

# %%
#bar plot 
categories=['A','B','C','D']
value=[2,5,4,6]

plt.bar(categories,value,color="purple")
plt.xlabel("categories")
plt.ylabel("value")
plt.title("bar plot")
plt.show()

# %%
# HIST plot
data=[1,2,2,2,2,2,4,4,7,5,7,6,6,6,3]
plt.hist(data,bins=7,color='orange',edgecolor='black')
# Out:
# (array([1., 5., 1., 2., 1., 3., 2.]),
#  array([1.        , 1.85714286, 2.71428571, 3.57142857, 4.42857143,
#         5.28571429, 6.14285714, 7.        ]),
#  <BarContainer object of 7 artists>)

# %%
#Scatter plot

x=[1,2,4,6,3]
y=[2,3,4,5,6]
plt.scatter(x,y,color='blue',marker='x')

# %%
### pie plot 
labels=['A','B','C','D']
size=[20,50,40,60]
color=['gold', 'yellow', 'blue', 'red']
explode=(0.2,0,0,0)

plt.pie(size,explode=explode, labels=labels,colors=color,autopct="%1.1f%%",shadow=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x24425bacf80>,
# ...
#  [Text(1.2122138991585567, 0.4696141636352219, 'A'),
#   Text(-0.1014952998678314, 1.0953075842450555, 'B'),
#   Text(-1.0812703710995255, -0.20212467583720345, 'C'),
#   Text(0.49031222266058644, -0.9846796049018359, 'D')],
#  [Text(0.7459777840975733, 0.28899333146782885, '11.8%'),
#   Text(-0.05536107265518076, 0.5974405004973029, '29.4%'),
#   Text(-0.5897838387815594, -0.11024982318392915, '23.5%'),
#   Text(0.267443030542138, -0.5370979663100922, '35.3%')])

# %%
# %pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
sales_data_df=pd.read_excel('SaleData.xlsx')
sales_data_df.head(5)
# Out:
#    OrderDate   Region  Manager   SalesMan          Item  Units  Unit_price  \
# 0 2018-01-06     East   Martha  Alexander    Television   95.0      1198.0
# 1 2018-01-23  Central  Hermann     Shelli  Home Theater   50.0       500.0
# 2 2018-02-09  Central  Hermann       Luis    Television   36.0      1198.0
# 3 2018-02-26  Central  Timothy      David    Cell Phone   27.0       225.0
# 4 2018-03-15     West  Timothy    Stephen    Television   56.0      1198.0
#
#    Sale_amt
# 0  113810.0
# 1   25000.0
# 2   43128.0
# 3    6075.0
# 4   67088.0

# %%
sales_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45 entries, 0 to 44
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   OrderDate   43 non-null     datetime64[ns]
#  1   Region      43 non-null     object
#  2   Manager     43 non-null     object
#  3   SalesMan    43 non-null     object
#  4   Item        43 non-null     object
#  5   Units       45 non-null     float64
#  6   Unit_price  45 non-null     float64
#  7   Sale_amt    45 non-null     float64
# dtypes: datetime64[ns](1), float64(3), object(4)
# memory usage: 2.9+ KB

# %%
Total_sales_value=sales_data_df.groupby('Item')['Unit_price'].sum()
Total_sales_value
# Out:
# Item
# Cell Phone       1125.0
# Desk              375.0
# Home Theater     7500.0
# Television      15574.0
# Video Games       409.5
# Name: Unit_price, dtype: float64

# %%
Total_sales_value.plot(kind='bar',color='teal')
# Out:
# <Axes: xlabel='Item'>

# %%
sales_trends = sales_data_df.groupby('OrderDate')['Unit_price'].sum().reset_index()
plt.plot(sales_trends['OrderDate'], sales_trends['Unit_price'])
