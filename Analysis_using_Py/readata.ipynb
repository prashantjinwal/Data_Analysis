# %%
import pandas as pd
from io import StringIO

Data = '{"Name": "John", "email":"John123@gmail.com", "job":[{"title1":"webdev", "title2":"Juicewala"}]}'
df = pd.read_json(StringIO(Data))
df
# Out:
#    Name              email                                          job
# 0  John  John123@gmail.com  {'title1': 'webdev', 'title2': 'Juicewala'}

# %%
df.to_json()
# Out:
# '{"Name":{"0":"John"},"email":{"0":"John123@gmail.com"},"job":{"0":{"title1":"webdev","title2":"Juicewala"}}}'

# %%
df.to_json(orient='records')
# Out:
# '[{"Name":"John","email":"John123@gmail.com","job":{"title1":"webdev","title2":"Juicewala"}}]'

# %%
df= pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/wine/wine.data")

# %%
df
# Out:
#      1  14.23  1.71  2.43  15.6  127   2.8  3.06   .28  2.29   5.64  1.04  \
# 0    1  13.20  1.78  2.14  11.2  100  2.65  2.76  0.26  1.28   4.38  1.05
# 1    1  13.16  2.36  2.67  18.6  101  2.80  3.24  0.30  2.81   5.68  1.03
# 2    1  14.37  1.95  2.50  16.8  113  3.85  3.49  0.24  2.18   7.80  0.86
# 3    1  13.24  2.59  2.87  21.0  118  2.80  2.69  0.39  1.82   4.32  1.04
# 4    1  14.20  1.76  2.45  15.2  112  3.27  3.39  0.34  1.97   6.75  1.05
# ..  ..    ...   ...   ...   ...  ...   ...   ...   ...   ...    ...   ...
# 172  3  13.71  5.65  2.45  20.5   95  1.68  0.61  0.52  1.06   7.70  0.64
# 173  3  13.40  3.91  2.48  23.0  102  1.80  0.75  0.43  1.41   7.30  0.70
# 174  3  13.27  4.28  2.26  20.0  120  1.59  0.69  0.43  1.35  10.20  0.59
# 175  3  13.17  2.59  2.37  20.0  120  1.65  0.68  0.53  1.46   9.30  0.60
# 176  3  14.13  4.10  2.74  24.5   96  2.05  0.76  0.56  1.35   9.20  0.61
#
#      3.92  1065
# 0    3.40  1050
# 1    3.17  1185
# 2    3.45  1480
# 3    2.93   735
# 4    2.85  1450
# ..    ...   ...
# 172  1.74   740
# 173  1.56   750
# 174  1.56   835
# 175  1.62   840
# 176  1.60   560
#
# [177 rows x 14 columns]

# %%
df.to_csv("wine.csv")

# %%
# !pip install lxml
# !pip install html5lib
# !pip beautisoup4
# Out:
# Requirement already satisfied: lxml in c:\users\prash\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (5.4.0)
# [notice] A new release of pip is available: 24.0 -> 25.1.1
# [notice] To update, run: C:\Users\prash\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# Requirement already satisfied: html5lib in c:\users\prash\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (1.1)
# Requirement already satisfied: six>=1.9 in c:\users\prash\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from html5lib) (1.17.0)
# Requirement already satisfied: webencodings in c:\users\prash\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from html5lib) (0.5.1)
# [notice] A new release of pip is available: 24.0 -> 25.1.1
# [notice] To update, run: C:\Users\prash\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# ERROR: unknown command "beautisoup4"

# %%
url="https://www.fdic.gov/bank-failures/failed-bank-list"
ht = pd.read_html(url)
ht[0]
# Out:
#                                Bank Name               City         State  \
# 0                   Pulaski Savings Bank            Chicago      Illinois
# 1     The First National Bank of Lindsay            Lindsay      Oklahoma
# 2  Republic First Bank dba Republic Bank       Philadelphia  Pennsylvania
# 3                          Citizens Bank           Sac City          Iowa
# 4               Heartland Tri-State Bank            Elkhart        Kansas
# 5                    First Republic Bank      San Francisco    California
# 6                         Signature Bank           New York      New York
# 7                    Silicon Valley Bank        Santa Clara    California
# 8                      Almena State Bank             Almena        Kansas
# 9             First City Bank of Florida  Fort Walton Beach       Florida
#
#     Cert                Acquiring Institution      Closing Date  \
# 0  28611                      Millennium Bank  January 17, 2025
# 1   4134   First Bank & Trust Co., Duncan, OK  October 18, 2024
# 2  27332    Fulton Bank, National Association    April 26, 2024
# 3   8758            Iowa Trust & Savings Bank  November 3, 2023
# 4  25851               Dream First Bank, N.A.     July 28, 2023
# 5  59017            JPMorgan Chase Bank, N.A.       May 1, 2023
# 6  57053                  Flagstar Bank, N.A.    March 12, 2023
# 7  24735  First Citizens Bank & Trust Company    March 10, 2023
# 8  15426                          Equity Bank  October 23, 2020
# 9  16748            United Fidelity Bank, fsb  October 16, 2020
#
#    Fund  Sort ascending
# 0                 10548
# 1                 10547
# 2                 10546
# 3                 10545
# 4                 10544
# 5                 10543
# 6                 10540
# 7                 10539
# 8                 10538
# 9                 10537

# %%
# also use read_excel ..download openpyxl
