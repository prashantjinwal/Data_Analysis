# %%
import seaborn as sns 
df = sns.load_dataset('tips')

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.to_csv('tips.csv')

# %%
from autoviz.AutoViz_Class import AutoViz_Class
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 from autoviz.AutoViz_Class import AutoViz_Class
#
# File g:\Data_Analyst\venv\Lib\site-packages\autoviz\AutoViz_Class.py:43
#      40 import io
#      41 # ipython inline magic shouldn't be needed because all plots are
#      42 # being displayed with plt.show() calls
# ---> 43 get_ipython().magic('matplotlib inline')
#      44 import seaborn as sns
#      45 sns.set(style="whitegrid", color_codes=True)
#
# AttributeError: 'ZMQInteractiveShell' object has no attribute 'magic'
